# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import warnings
warnings.filterwarnings("ignore")

sns.set_style('darkgrid')

# %%
players = pd.read_csv('players.csv')

# %%
players.tail()
# Out:
#           date player_name       team   opponent country  player_id  match_id  \
# 383312  735878      kIMERA    ExAequo  RIP Fonty   Italy       7607   2298497
# 383313  735878   morphiw0w    ExAequo  RIP Fonty   Italy       9752   2298497
# 383314  735878     overfly  RIP Fonty    ExAequo   Italy       7698   2298497
# 383315  735878     simozor  RIP Fonty    ExAequo   Italy       9753   2298497
# 383316  735878       xullE  RIP Fonty    ExAequo   Italy       9754   2298497
#
#         event_id                              event_name  best_of  \
# 383312      1957  Milan Games Week 2015 League by FACEIT        2
# 383313      1957  Milan Games Week 2015 League by FACEIT        2
# 383314      1957  Milan Games Week 2015 League by FACEIT        2
# 383315      1957  Milan Games Week 2015 League by FACEIT        2
# 383316      1957  Milan Games Week 2015 League by FACEIT        2
#
#               map_1  map_2 map_3  kills  assists  deaths  hs  flash_assists  \
# 383312  Cobblestone  Cache   NaN     30        2      17   8            NaN
# 383313  Cobblestone  Cache   NaN     26        6      22   9            NaN
# 383314  Cobblestone  Cache   NaN     28        4      34   8            NaN
# 383315  Cobblestone  Cache   NaN     18        7      36   9            NaN
# 383316  Cobblestone  Cache   NaN     14        2      35   7            NaN
#
#         kast  kddiff  adr  fkdiff  rating  m1_kills  m1_assists  m1_deaths  \
# 383312   NaN      13  NaN       2    1.29        15           0          4
# 383313   NaN       4  NaN       0    1.00        14           1          6
# 383314   NaN      -6  NaN       2    0.81         8           1         16
# 383315   NaN     -18  NaN      -4    0.50         5           0         17
# 383316   NaN     -21  NaN       0    0.44         5           1         16
#
#         m1_hs  m1_flash_assists  m1_kast  m1_kddiff  m1_adr  m1_fkdiff  \
# 383312      2               NaN      NaN         11     NaN          1
# 383313      7               NaN      NaN          8     NaN          0
# 383314      3               NaN      NaN         -8     NaN         -1
# 383315      2               NaN      NaN        -12     NaN          0
# 383316      3               NaN      NaN        -11     NaN          0
#
#         m1_rating  m2_kills  m2_assists  m2_deaths  m2_hs  m2_flash_assists  \
# 383312       1.63      15.0         2.0       13.0    6.0               NaN
# 383313       1.32      12.0         5.0       16.0    2.0               NaN
# 383314       0.44      20.0         3.0       18.0    5.0               NaN
# 383315       0.25      13.0         7.0       19.0    7.0               NaN
# 383316       0.33       9.0         1.0       19.0    4.0               NaN
#
#         m2_kast  m2_kddiff  m2_adr  m2_fkdiff  m2_rating  m3_kills  \
# 383312      NaN        2.0     NaN        1.0       1.06       NaN
# 383313      NaN       -4.0     NaN        0.0       0.79       NaN
# 383314      NaN        2.0     NaN        3.0       1.06       NaN
# 383315      NaN       -6.0     NaN       -4.0       0.68       NaN
# 383316      NaN      -10.0     NaN        0.0       0.52       NaN
#
#         m3_assists  m3_deaths  m3_hs  m3_flash_assists  m3_kast  m3_kddiff  \
# 383312         NaN        NaN    NaN               NaN      NaN        NaN
# 383313         NaN        NaN    NaN               NaN      NaN        NaN
# 383314         NaN        NaN    NaN               NaN      NaN        NaN
# 383315         NaN        NaN    NaN               NaN      NaN        NaN
# 383316         NaN        NaN    NaN               NaN      NaN        NaN
#
#         m3_adr  m3_fkdiff  m3_rating  kills_ct  deaths_ct  kddiff_ct  adr_ct  \
# 383312     NaN        NaN        NaN       NaN        NaN        NaN     NaN
# 383313     NaN        NaN        NaN       NaN        NaN        NaN     NaN
# 383314     NaN        NaN        NaN       NaN        NaN        NaN     NaN
# 383315     NaN        NaN        NaN       NaN        NaN        NaN     NaN
# 383316     NaN        NaN        NaN       NaN        NaN        NaN     NaN
#
#         kast_ct  rating_ct  kills_t  deaths_t  kddiff_t  adr_t  kast_t  \
# 383312      NaN        NaN      NaN       NaN       NaN    NaN     NaN
# 383313      NaN        NaN      NaN       NaN       NaN    NaN     NaN
# 383314      NaN        NaN      NaN       NaN       NaN    NaN     NaN
# 383315      NaN        NaN      NaN       NaN       NaN    NaN     NaN
# 383316      NaN        NaN      NaN       NaN       NaN    NaN     NaN
#
#         rating_t  m1_kills_ct  m1_deaths_ct  m1_kddiff_ct  m1_adr_ct  \
# 383312       NaN          NaN           NaN           NaN        NaN
# 383313       NaN          NaN           NaN           NaN        NaN
# 383314       NaN          NaN           NaN           NaN        NaN
# 383315       NaN          NaN           NaN           NaN        NaN
# 383316       NaN          NaN           NaN           NaN        NaN
#
#         m1_kast_ct  m1_rating_ct  m1_kills_t  m1_deaths_t  m1_kddiff_t  \
# 383312         NaN           NaN         NaN          NaN          NaN
# 383313         NaN           NaN         NaN          NaN          NaN
# 383314         NaN           NaN         NaN          NaN          NaN
# 383315         NaN           NaN         NaN          NaN          NaN
# 383316         NaN           NaN         NaN          NaN          NaN
#
#         m1_adr_t  m1_kast_t  m1_rating_t  m2_kills_ct  m2_deaths_ct  \
# 383312       NaN        NaN          NaN          NaN           NaN
# 383313       NaN        NaN          NaN          NaN           NaN
# 383314       NaN        NaN          NaN          NaN           NaN
# 383315       NaN        NaN          NaN          NaN           NaN
# 383316       NaN        NaN          NaN          NaN           NaN
#
#         m2_kddiff_ct  m2_adr_ct  m2_kast_ct  m2_rating_ct  m2_kills_t  \
# 383312           NaN        NaN         NaN           NaN         NaN
# 383313           NaN        NaN         NaN           NaN         NaN
# 383314           NaN        NaN         NaN           NaN         NaN
# 383315           NaN        NaN         NaN           NaN         NaN
# 383316           NaN        NaN         NaN           NaN         NaN
#
#         m2_deaths_t  m2_kddiff_t  m2_adr_t  m2_kast_t  m2_rating_t  \
# 383312          NaN          NaN       NaN        NaN          NaN
# 383313          NaN          NaN       NaN        NaN          NaN
# 383314          NaN          NaN       NaN        NaN          NaN
# 383315          NaN          NaN       NaN        NaN          NaN
# 383316          NaN          NaN       NaN        NaN          NaN
#
#         m3_kills_ct  m3_deaths_ct  m3_kddiff_ct  m3_adr_ct  m3_kast_ct  \
# 383312          NaN           NaN           NaN        NaN         NaN
# 383313          NaN           NaN           NaN        NaN         NaN
# 383314          NaN           NaN           NaN        NaN         NaN
# 383315          NaN           NaN           NaN        NaN         NaN
# 383316          NaN           NaN           NaN        NaN         NaN
#
#         m3_rating_ct  m3_kills_t  m3_deaths_t  m3_kddiff_t  m3_adr_t  \
# 383312           NaN         NaN          NaN          NaN       NaN
# 383313           NaN         NaN          NaN          NaN       NaN
# 383314           NaN         NaN          NaN          NaN       NaN
# 383315           NaN         NaN          NaN          NaN       NaN
# 383316           NaN         NaN          NaN          NaN       NaN
#
#         m3_kast_t  m3_rating_t
# 383312        NaN          NaN
# 383313        NaN          NaN
# 383314        NaN          NaN
# 383315        NaN          NaN
# 383316        NaN          NaN

# %%
def draw_missing_data_table(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

missing = draw_missing_data_table(players)

# %%
missing[missing['Percent'] > 0].transpose()
# Out:
#             m3_kast_ct      m3_kast_t    m3_rating_t       m3_adr_t  \
# Total    337301.000000  337295.000000  337165.000000  337165.000000
# Percent       0.879953       0.879937       0.879598       0.879598
#
#            m3_kddiff_t    m3_deaths_t     m3_kills_t  m3_rating_ct  \
# Total    337165.000000  337165.000000  337165.000000  337154.00000
# Percent       0.879598       0.879598       0.879598       0.87957
#
#             m3_adr_ct  m3_kddiff_ct  m3_deaths_ct   m3_kills_ct  \
# Total    337154.00000  337154.00000  337154.00000  337154.00000
# Percent       0.87957       0.87957       0.87957       0.87957
#
#          m3_flash_assists         m3_adr        m3_kast       m3_kills  \
# Total       334600.000000  317813.000000  317793.000000  314801.000000
# Percent          0.872907       0.829113       0.829061       0.821255
#
#              m3_rating     m3_assists      m3_deaths          m3_hs  \
# Total    314801.000000  314801.000000  314801.000000  314801.000000
# Percent       0.821255       0.821255       0.821255       0.821255
#
#              m3_kddiff      m3_fkdiff          map_3      m2_kast_t  \
# Total    314801.000000  314801.000000  314639.000000  255763.000000
# Percent       0.821255       0.821255       0.820832       0.667236
#
#             m2_kast_ct    m2_kddiff_t    m2_rating_t       m2_adr_t  \
# Total    255750.000000  255383.000000  255383.000000  255383.000000
# Percent       0.667202       0.666245       0.666245       0.666245
#
#            m2_deaths_t     m2_kills_t      m2_adr_ct   m2_rating_ct  \
# Total    255383.000000  255383.000000  255314.000000  255314.000000
# Percent       0.666245       0.666245       0.666065       0.666065
#
#            m2_kills_ct   m2_deaths_ct   m2_kddiff_ct  m2_flash_assists  \
# Total    255313.000000  255313.000000  255313.000000       247201.0000
# Percent       0.666062       0.666062       0.666062            0.6449
#
#                 m2_adr        m2_kast          m2_hs      m2_fkdiff  \
# Total    196494.000000  196455.000000  187127.000000  187127.000000
# Percent       0.512615       0.512513       0.488178       0.488178
#
#              m2_rating      m2_kddiff      m2_deaths     m2_assists  \
# Total    187127.000000  187127.000000  187127.000000  187127.000000
# Percent       0.488178       0.488178       0.488178       0.488178
#
#               m2_kills          map_2      m1_kast_t     m1_kast_ct  \
# Total    187127.000000  186794.000000  124866.000000  124857.000000
# Percent       0.488178       0.487309       0.325751       0.325728
#
#             m1_kills_t    m1_rating_t    m1_deaths_t       m1_adr_t  \
# Total    124448.000000  124448.000000  124448.000000  124448.000000
# Percent       0.324661       0.324661       0.324661       0.324661
#
#            m1_kddiff_t   m1_kills_ct  m1_rating_ct  m1_kddiff_ct  \
# Total    124448.000000  124329.00000  124329.00000  124329.00000
# Percent       0.324661       0.32435       0.32435       0.32435
#
#          m1_deaths_ct     m1_adr_ct      rating_ct        kast_ct  \
# Total    124329.00000  124329.00000  123017.000000  123017.000000
# Percent       0.32435       0.32435       0.320928       0.320928
#
#                kills_t       kills_ct      kddiff_ct      deaths_ct  \
# Total    123017.000000  123017.000000  123017.000000  123017.000000
# Percent       0.320928       0.320928       0.320928       0.320928
#
#                 adr_ct       rating_t         kast_t          adr_t  \
# Total    123017.000000  123017.000000  123017.000000  123017.000000
# Percent       0.320928       0.320928       0.320928       0.320928
#
#               kddiff_t       deaths_t  m1_flash_assists  flash_assists  \
# Total    123017.000000  123017.000000     117063.000000  109792.000000
# Percent       0.320928       0.320928          0.305395       0.286426
#
#                m1_adr           adr          kast       m1_kast  player_name
# Total    16895.000000  16874.000000  16846.000000  16846.000000     1.000000
# Percent      0.044076      0.044021      0.043948      0.043948     0.000003

# %% [markdown]
# Since the percent of the missing values in kast, adr, player_name is quite low and just under 5%, we will just remove those rows.
#
# However, with flash_assists, we will remove the column for our model since 29% of the values are missing which is a significant chunk of the data.
#
# the m3... and m2... and their missing values are not as important because we're going to create columns that will average out the stats based on the games played in that specific series.

# %%
players.drop(players[pd.isnull(players['kast'])].index, inplace=True) 
players.drop(players[pd.isnull(players['adr'])].index, inplace=True) 
players.drop(players[pd.isnull(players['player_name'])].index, inplace=True) 
players.drop(['flash_assists'], axis=1, inplace=True)

# %% [markdown]
# kast, adr, fkdiff, rating, kddiff dont need to be averaged or changed
#
# kills, assists, deaths, hs, need to be averaged as new columns
#
# add maps_played column that shows how many maps were played in the series

# %%
players['m3_kills'].fillna(-1, inplace=True)
players['m3_assists'].fillna(-1, inplace=True)
players['m3_deaths'].fillna(-1, inplace=True)
players['m3_hs'].fillna(-1, inplace=True)

players['m2_kills'].fillna(-1, inplace=True)
players['m2_assists'].fillna(-1, inplace=True)
players['m2_deaths'].fillna(-1, inplace=True)
players['m2_hs'].fillna(-1, inplace=True)

# %%
missing = draw_missing_data_table(players)
missing[missing['Percent'] > 0].transpose()
# Out:
#             m3_kast_ct      m3_kast_t    m3_rating_t       m3_adr_t  \
# Total    320426.000000  320420.000000  320290.000000  320290.000000
# Percent       0.874425       0.874409       0.874054       0.874054
#
#            m3_kddiff_t    m3_deaths_t     m3_kills_t   m3_rating_ct  \
# Total    320290.000000  320290.000000  320290.000000  320279.000000
# Percent       0.874054       0.874054       0.874054       0.874024
#
#              m3_adr_ct   m3_kddiff_ct   m3_deaths_ct    m3_kills_ct  \
# Total    320279.000000  320279.000000  320279.000000  320279.000000
# Percent       0.874024       0.874024       0.874024       0.874024
#
#          m3_flash_assists         m3_adr      m3_fkdiff      m3_rating  \
# Total       317972.000000  300938.000000  300918.000000  300918.000000
# Percent          0.867728       0.821243       0.821189       0.821189
#
#              m3_kddiff        m3_kast          map_3      m2_kast_t  \
# Total    300918.000000  300918.000000  300767.000000  238888.000000
# Percent       0.821189       0.821189       0.820777       0.651912
#
#             m2_kast_ct    m2_rating_t    m2_kddiff_t       m2_adr_t  \
# Total    238875.000000  238508.000000  238508.000000  238508.000000
# Percent       0.651877       0.650875       0.650875       0.650875
#
#            m2_deaths_t     m2_kills_t   m2_rating_ct      m2_adr_ct  \
# Total    238508.000000  238508.000000  238439.000000  238439.000000
# Percent       0.650875       0.650875       0.650687       0.650687
#
#           m2_kddiff_ct    m2_kills_ct   m2_deaths_ct  m2_flash_assists  \
# Total    238438.000000  238438.000000  238438.000000     231120.000000
# Percent       0.650684       0.650684       0.650684          0.630714
#
#                m2_adr        m2_kast      m2_kddiff      m2_rating  \
# Total    179619.00000  179601.000000  179600.000000  179600.000000
# Percent       0.49017       0.490121       0.490118       0.490118
#
#              m2_fkdiff          map_2      m1_kast_t    m1_kast_ct  \
# Total    179600.000000  179299.000000  107992.000000  107983.00000
# Percent       0.490118       0.489297       0.294704       0.29468
#
#            m1_rating_t     m1_kills_t    m1_deaths_t    m1_kddiff_t  \
# Total    107574.000000  107574.000000  107574.000000  107574.000000
# Percent       0.293564       0.293564       0.293564       0.293564
#
#               m1_adr_t    m1_kills_ct   m1_deaths_ct   m1_kddiff_ct  \
# Total    107574.000000  107455.000000  107455.000000  107455.000000
# Percent       0.293564       0.293239       0.293239       0.293239
#
#           m1_rating_ct      m1_adr_ct       kills_ct        kills_t  \
# Total    107455.000000  107455.000000  106146.000000  106146.000000
# Percent       0.293239       0.293239       0.289667       0.289667
#
#              deaths_ct      kddiff_ct         kast_t       rating_t  \
# Total    106146.000000  106146.000000  106146.000000  106146.000000
# Percent       0.289667       0.289667       0.289667       0.289667
#
#                 adr_ct        kast_ct      rating_ct       deaths_t  \
# Total    106146.000000  106146.000000  106146.000000  106146.000000
# Percent       0.289667       0.289667       0.289667       0.289667
#
#               kddiff_t          adr_t  m1_flash_assists     m1_adr
# Total    106146.000000  106146.000000     101501.000000  21.000000
# Percent       0.289667       0.289667          0.276991   0.000057

# %%
players['best_of'].value_counts()
# Out:
# 1    177929
# 3    170672
# 2     14406
# 5      3435
# Name: best_of, dtype: int64

# %%
players.drop(players[players['best_of'] ==  5].index, inplace=True)

# %%
players['best_of'].value_counts()
# Out:
# 1    177929
# 3    170672
# 2     14406
# Name: best_of, dtype: int64

# %%
def maps_played(df):
    if df['best_of'] == 1:
        return 1
    elif df['best_of'] == 2:
        return 2
    else:
        if (df['m3_kills'] == -1) or (df['m3_assists'] == -1) or (df['m3_deaths'] == -1) or (df['m3_hs'] == -1):
            return 2
        else: 
            return 3
players['maps_played'] = players.apply(maps_played, axis=1)
players['maps_played'].value_counts()
# Out:
# 1    177929
# 2    122391
# 3     62687
# Name: maps_played, dtype: int64

# %%
def avg_kills(df):
    if df['maps_played'] == 1:
        return df['m1_kills']
    elif df['maps_played'] == 2:
        return (df['m1_kills'] + df['m2_kills'])/2
    else:
        return (df['m1_kills'] + df['m2_kills'] + df['m3_kills'])/3

def avg_assists(df):
    if df['maps_played'] == 1:
        return df['m1_assists']
    elif df['maps_played'] == 2:
        return (df['m1_assists'] + df['m2_assists'])/2
    else:
        return (df['m1_assists'] + df['m2_assists'] + df['m2_assists'])/3

def avg_deaths(df):
    if df['maps_played'] == 1:
        return df['m1_deaths']
    elif df['maps_played'] == 2:
        return (df['m1_deaths'] + df['m2_deaths'])/2
    else:
        return (df['m1_deaths'] + df['m2_deaths'] + df['m3_deaths'])/3

def avg_hs(df):
    if df['maps_played'] == 1:
        return df['m1_hs']
    elif df['maps_played'] == 2:
        return (df['m1_hs'] + df['m1_hs'])/2
    else:
        return (df['m1_hs'] + df['m2_hs'] + df['m3_hs'])/3
    
players['avg_kills'] = players.apply(avg_kills, axis=1)
players['avg_assists'] = players.apply(avg_assists, axis=1)
players['avg_deaths'] = players.apply(avg_deaths, axis=1)
players['avg_hs'] = players.apply(avg_hs, axis=1)

# %%
print(players[players['avg_kills'] < 0].shape, players[players['avg_assists'] < 0].shape, players[players['avg_deaths'] < 0].shape, players[players['avg_hs'] < 0].shape)
# Out:
# (5, 105) (62, 105) (0, 105) (0, 105)

# %%
players.drop(players[players['avg_kills'] < 0].index, inplace=True)
players.drop(players[players['avg_assists'] < 0].index, inplace=True)

# %%
f, ax = plt.subplots(2, 2, figsize=(12,10))
sns.distplot(x=players['avg_kills'], kde=False, ax=ax[0,0], bins=20)
ax[0,0].set_xlabel('Average Kills', fontsize=15)
ax[0,0].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_assists'], kde=False, ax=ax[0,1], bins=20)
ax[0,1].set_xlabel('Average Assists', fontsize=15)
ax[0,1].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_deaths'], kde=False, ax=ax[1,0], bins=20)
ax[1,0].set_xlabel('Average Deaths', fontsize=15)
ax[1,0].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_hs'], kde=False, ax=ax[1,1], bins=20)
ax[1,1].set_xlabel('Average Headshots', fontsize=15)
ax[1,1].set_ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x=players['maps_played'], y=players['avg_kills'], ax=ax)
ax.set_xlabel('Maps Played', fontsize=15)
ax.set_ylabel('Average Kills', fontsize=15)
# Out:
# Text(0, 0.5, 'Average Kills')

# %%
f, ax = plt.subplots(2, 2, figsize=(12,10))
sns.distplot(x=players['avg_kills'], kde=False, ax=ax[0,0], bins=20)
ax[0,0].set_xlabel('Average Kills', fontsize=15)
ax[0,0].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_assists'], kde=False, ax=ax[0,1], bins=20)
ax[0,1].set_xlabel('Average Assists', fontsize=15)
ax[0,1].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_deaths'], kde=False, ax=ax[1,0], bins=20)
ax[1,0].set_xlabel('Average Deaths', fontsize=15)
ax[1,0].set_ylabel('Frequency', fontsize=15)

sns.distplot(x=players['avg_hs'], kde=False, ax=ax[1,1], bins=20)
ax[1,1].set_xlabel('Average Headshots', fontsize=15)
ax[1,1].set_ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
f, ax = plt.subplots(2, 2, figsize=(16,10))
sns.boxplot(x=players['maps_played'], y=players['avg_kills'], ax=ax[0,0])
ax[0,0].set_xlabel('Maps Played', fontsize=15)
ax[0,0].set_ylabel('Average Kills', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_assists'], ax=ax[0,1])
ax[0,1].set_xlabel('Maps Played', fontsize=15)
ax[0,1].set_ylabel('Average Assists', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_deaths'], ax=ax[1,0])
ax[1,0].set_xlabel('Maps Played', fontsize=15)
ax[1,0].set_ylabel('Average Deaths', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_hs'], ax=ax[1,1])
ax[1,1].set_xlabel('Maps Played', fontsize=15)
ax[1,1].set_ylabel('Average Headshots', fontsize=15)
# Out:
# Text(0, 0.5, 'Average Headshots')

# %% [markdown]
# From the boxplot of avg_kills values with 1 map played, the outliers for the column are a part of that group of values. We see that most of the data is right-skewed.
#
# It seems like while 40-50 average kills is still atainable in best of 2s and 3s so we will drop the points that are above 45 average kills.
#
# We'll apply the same logic to the other 3 columns of data.

# %%
players.drop(players[players['avg_kills'] > 45].index, inplace=True)
players.drop(players[players['avg_assists'] > 12.5].index, inplace=True)
players.drop(players[players['avg_deaths'] > 35].index, inplace=True)
players.drop(players[players['avg_hs'] > 22.5].index, inplace=True)

# %%
f, ax = plt.subplots(2, 2, figsize=(16,10))
sns.boxplot(x=players['maps_played'], y=players['avg_kills'], ax=ax[0,0])
ax[0,0].set_xlabel('Maps Played', fontsize=15)
ax[0,0].set_ylabel('Average Kills', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_assists'], ax=ax[0,1])
ax[0,1].set_xlabel('Maps Played', fontsize=15)
ax[0,1].set_ylabel('Average Assists', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_deaths'], ax=ax[1,0])
ax[1,0].set_xlabel('Maps Played', fontsize=15)
ax[1,0].set_ylabel('Average Deaths', fontsize=15)

sns.boxplot(x=players['maps_played'], y=players['avg_hs'], ax=ax[1,1])
ax[1,1].set_xlabel('Maps Played', fontsize=15)
ax[1,1].set_ylabel('Average Headshots', fontsize=15)
# Out:
# Text(0, 0.5, 'Average Headshots')

# %%
sns.heatmap(players[['avg_kills', 'avg_assists', 'avg_deaths', 'avg_hs']].corr())
# Out:
# <AxesSubplot:>

# %%
players = players.drop(players.loc[:, 'm1_kills':'m3_rating_t'].columns, axis = 1).head()

# %%
players.head()
# Out:
#      date player_name           team       opponent        country  player_id  \
# 0  737481      Brehze  Evil Geniuses         Liquid  United States       9136
# 1  737481        CeRq  Evil Geniuses         Liquid       Bulgaria      11219
# 2  737481       EliGE         Liquid  Evil Geniuses  United States       8738
# 3  737481       Ethan  Evil Geniuses         Liquid  United States      10671
# 4  737481         NAF         Liquid  Evil Geniuses         Canada       8520
#
#    match_id  event_id         event_name  best_of     map_1 map_2    map_3  \
# 0   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 1   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 2   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 3   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 4   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
#
#    kills  assists  deaths  hs  kast  kddiff   adr  fkdiff  rating  \
# 0     57       14      61  29  71.1      -4  79.9       0    1.04
# 1     54       10      54  18  65.1       0  71.7       2    0.98
# 2     55       10      51  28  67.5       4  77.9       1    1.08
# 3     43        5      54  18  65.1     -11  58.7      -4    0.83
# 4     52       22      46  23  77.1       6  75.9      -1    1.08
#
#    maps_played  avg_kills  avg_assists  avg_deaths    avg_hs
# 0            3  19.000000     5.666667   20.333333  9.666667
# 1            3  18.000000     4.666667   18.000000  6.000000
# 2            3  18.333333     3.000000   17.000000  9.333333
# 3            3  14.333333     2.333333   18.000000  6.000000
# 4            3  17.333333     5.666667   15.333333  7.666667

# %%
results.head()
# Out:
#      date               team_1          team_2     _map  score_1  score_2  \
# 0  737502              Recon 5         TeamOne    Dust2        0       16
# 1  737502              Recon 5         TeamOne  Inferno       13       16
# 2  737502  New England Whalers        Station7  Inferno       12       16
# 3  737502              Rugratz  Bad News Bears  Inferno        7       16
# 4  737502              Rugratz  Bad News Bears  Vertigo        8       16
#
#   map_winner starting_ct  ct_score_1  t_score_2  t_score_1  ct_score_2  \
# 0          2           2           0          1          0          15
# 1          2           2           8          6          5          10
# 2          2           1           9          6          3          10
# 3          2           2           0          8          7           8
# 4          2           2           4          5          4          11
#
#    event_id  match_id match_winner side_won_1 side_won_2  ht_score_1  \
# 0      5151   2340454            2          1          0           0
# 1      5151   2340454            2          0          0           5
# 2      5243   2340461            2          0          0           9
# 3      5151   2340453            2          1          0           7
# 4      5151   2340453            2          1          0           4
#
#    ht_score_2
# 0          15
# 1          10
# 2           6
# 3           8
# 4          11

# %%
merged_left = pd.merge(left=players, right=results, how='left', left_on='match_id', right_on='match_id')
merged_left.dropna().head()
# Out:
#    date_x player_name           team opponent        country  player_id  \
# 0  737481      Brehze  Evil Geniuses   Liquid  United States       9136
# 1  737481      Brehze  Evil Geniuses   Liquid  United States       9136
# 2  737481      Brehze  Evil Geniuses   Liquid  United States       9136
# 3  737481        CeRq  Evil Geniuses   Liquid       Bulgaria      11219
# 4  737481        CeRq  Evil Geniuses   Liquid       Bulgaria      11219
#
#    match_id  event_id_x         event_name  best_of     map_1 map_2    map_3  \
# 0   2339385        4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 1   2339385        4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 2   2339385        4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 3   2339385        4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 4   2339385        4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
#
#    kills  assists  deaths  hs  kast  kddiff   adr  fkdiff  rating  \
# 0     57       14      61  29  71.1      -4  79.9       0    1.04
# 1     57       14      61  29  71.1      -4  79.9       0    1.04
# 2     57       14      61  29  71.1      -4  79.9       0    1.04
# 3     54       10      54  18  65.1       0  71.7       2    0.98
# 4     54       10      54  18  65.1       0  71.7       2    0.98
#
#    maps_played  avg_kills  avg_assists  avg_deaths    avg_hs  date_y  team_1  \
# 0            3       19.0     5.666667   20.333333  9.666667  737481  Liquid
# 1            3       19.0     5.666667   20.333333  9.666667  737481  Liquid
# 2            3       19.0     5.666667   20.333333  9.666667  737481  Liquid
# 3            3       18.0     4.666667   18.000000  6.000000  737481  Liquid
# 4            3       18.0     4.666667   18.000000  6.000000  737481  Liquid
#
#           team_2      _map  score_1  score_2 map_winner starting_ct  \
# 0  Evil Geniuses      Nuke       15       19          2           1
# 1  Evil Geniuses  Overpass       16        7          1           2
# 2  Evil Geniuses   Inferno       16       10          1           2
# 3  Evil Geniuses      Nuke       15       19          2           1
# 4  Evil Geniuses  Overpass       16        7          1           2
#
#    ct_score_1  t_score_2  t_score_1  ct_score_2  event_id_y match_winner  \
# 0          11          4          4          11        4901            1
# 1           7          1          9           6        4901            1
# 2           7          4          9           6        4901            1
# 3          11          4          4          11        4901            1
# 4           7          1          9           6        4901            1
#
#   side_won_1 side_won_2  ht_score_1  ht_score_2
# 0          0          0          11           4
# 1          0          1           9           6
# 2          0          1           9           6
# 3          0          0          11           4
# 4          0          1           9           6

# %%
players[players['match_id'] == 2339385]
# Out:
#      date player_name           team       opponent        country  player_id  \
# 0  737481      Brehze  Evil Geniuses         Liquid  United States       9136
# 1  737481        CeRq  Evil Geniuses         Liquid       Bulgaria      11219
# 2  737481       EliGE         Liquid  Evil Geniuses  United States       8738
# 3  737481       Ethan  Evil Geniuses         Liquid  United States      10671
# 4  737481         NAF         Liquid  Evil Geniuses         Canada       8520
#
#    match_id  event_id         event_name  best_of     map_1 map_2    map_3  \
# 0   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 1   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 2   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 3   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
# 4   2339385      4901  IEM Katowice 2020        3  Overpass  Nuke  Inferno
#
#    kills  assists  deaths  hs  kast  kddiff   adr  fkdiff  rating  \
# 0     57       14      61  29  71.1      -4  79.9       0    1.04
# 1     54       10      54  18  65.1       0  71.7       2    0.98
# 2     55       10      51  28  67.5       4  77.9       1    1.08
# 3     43        5      54  18  65.1     -11  58.7      -4    0.83
# 4     52       22      46  23  77.1       6  75.9      -1    1.08
#
#    maps_played  avg_kills  avg_assists  avg_deaths    avg_hs
# 0            3  19.000000     5.666667   20.333333  9.666667
# 1            3  18.000000     4.666667   18.000000  6.000000
# 2            3  18.333333     3.000000   17.000000  9.333333
# 3            3  14.333333     2.333333   18.000000  6.000000
# 4            3  17.333333     5.666667   15.333333  7.666667
